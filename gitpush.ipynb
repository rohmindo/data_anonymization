# %%
# !ls

# %%
cd drive/MyDrive/mindoRoh_intern/

# %%
# !git init

# %%
# !git add *.ipynb

# %%
# !git config --global user.email "rohmindo@ajou.ac.kr"
# !git config --global user.name "rohmindo"

# %%
# !git commit -m "Anonimization"

# %%
# !git remote rm origin

# %%
# !git remote add origin https://rohmindo:a1541s1541@github.com/rohmindo/data_anonymization.git

# %%
# !git push -u origin master

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/My Drive/mindoRoh_intern/mydataset/.kaggle/"   
from google.colab import drive

# %%
cd mydataset/

# %%
# !kaggle datasets download -d akkithetechie/furniture-detector

# %%
# !unzip furniture-detector.zip

# %%
# !pwd

# %%
# !ls

# %%
cd .kaggle

# %%
from os import remove
root_dir = '/content/drive/MyDrive/mindoRoh_intern/mydataset/test/table'

# %%
#파일 저장하기
c=0;
for (root, dirs, files) in os.walk(root_dir):
    if len(files) > 0:
        for file_name in files:
                c=c+1
                img_path = root + '/' + file_name
                #image = cv2.imread(img_path)
                #output_image = cv2.GaussianBlur(image, (0, 0), 7)
                #output_path=img_path.replace('train','Gaussian_train')
                #temp=file_name.replace('.jpg','')
                print(c)
                #if c>400 :
                #  remove(img_path)
                #print(image_path)
                #if int(temp)>400 :
                
                #  print(img_path)
#                
 #               3cv2.imwrite(output_path,output_image)
