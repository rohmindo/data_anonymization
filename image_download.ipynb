# %%
# !git clone https://github.com/Joeclinton1/google-images-download.git
# Out:
# Cloning into 'google-images-download'...
# remote: Enumerating objects: 682, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 682 (delta 5), reused 10 (delta 5), pack-reused 666
# Receiving objects: 100% (682/682), 312.29 KiB | 1.26 MiB/s, done.
# Resolving deltas: 100% (395/395), done.

# %%
# !pwd
# Out:
# /content

# %%
cd drive/MyDrive/mindoRoh_intern/
# Out:
# /content/drive/MyDrive/mindoRoh_intern

# %%
cd google-images-download/
# Out:
# /content/drive/MyDrive/mindoRoh_intern/google-images-download

# %%
# !python setup.py install
# Out:
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#   % (opt, underscore_opt))
# running install
# running bdist_egg
# running egg_info
# writing google_images_download.egg-info/PKG-INFO
# writing dependency_links to google_images_download.egg-info/dependency_links.txt
# writing entry points to google_images_download.egg-info/entry_points.txt
# writing requirements to google_images_download.egg-info/requires.txt
# writing top-level names to google_images_download.egg-info/top_level.txt
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'README.md'
# writing manifest file 'google_images_download.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/google_images_download
# copying build/lib/google_images_download/sample_config.json -> build/bdist.linux-x86_64/egg/google_images_download
# copying build/lib/google_images_download/__init__.py -> build/bdist.linux-x86_64/egg/google_images_download
# copying build/lib/google_images_download/google_images_download.py -> build/bdist.linux-x86_64/egg/google_images_download
# copying build/lib/google_images_download/__main__.py -> build/bdist.linux-x86_64/egg/google_images_download
# byte-compiling build/bdist.linux-x86_64/egg/google_images_download/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/google_images_download/google_images_download.py to google_images_download.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/google_images_download/__main__.py to __main__.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying google_images_download.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying google_images_download.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying google_images_download.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying google_images_download.egg-info/entry_points.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying google_images_download.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying google_images_download.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating 'dist/google_images_download-2.8.0-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing google_images_download-2.8.0-py3.7.egg
# Copying google_images_download-2.8.0-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding google-images-download 2.8.0 to easy-install.pth file
# Installing googleimagesdownload script to /usr/local/bin
#
# Installed /usr/local/lib/python3.7/dist-packages/google_images_download-2.8.0-py3.7.egg
# Processing dependencies for google-images-download==2.8.0
# Searching for selenium
# Reading https://pypi.org/simple/selenium/
# Downloading https://files.pythonhosted.org/packages/d6/89/b70e657ffd2db2d917385ebf0a6aefb8f7613416607d07c80ab907e6328f/selenium-4.0.0.b4-py3-none-any.whl#sha256=a939ef1ba6e422252baa35a8541b87b7155f57491d97059bfe56b3dc3aa7ae0d
# Best match: selenium 4.0.0b4
# Processing selenium-4.0.0.b4-py3-none-any.whl
# Installing selenium-4.0.0.b4-py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding selenium 4.0.0b4 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/selenium-4.0.0b4-py3.7.egg
# Searching for urllib3[secure]~=1.26
# Reading https://pypi.org/simple/urllib3/
# Downloading https://files.pythonhosted.org/packages/5f/64/43575537846896abac0b15c3e5ac678d787a4021e906703f1766bfb8ea11/urllib3-1.26.6-py2.py3-none-any.whl#sha256=39fb8672126159acb139a7718dd10806104dec1e2f0f6c88aab05d17df10c8d4
# Best match: urllib3 1.26.6
# Processing urllib3-1.26.6-py2.py3-none-any.whl
# Installing urllib3-1.26.6-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding urllib3 1.26.6 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/urllib3-1.26.6-py3.7.egg
# Searching for trio~=0.17
# Reading https://pypi.org/simple/trio/
# Downloading https://files.pythonhosted.org/packages/35/c3/5a4befc3812b3b606e0ae9338bfdd02da3ad0a90df27dc66c37315e94f5c/trio-0.19.0-py3-none-any.whl#sha256=c27c231e66336183c484fbfe080fa6cc954149366c15dc21db8b7290081ec7b8
# Best match: trio 0.19.0
# Processing trio-0.19.0-py3-none-any.whl
# Installing trio-0.19.0-py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding trio 0.19.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/trio-0.19.0-py3.7.egg
# Searching for trio-websocket~=0.9
# Reading https://pypi.org/simple/trio-websocket/
# Downloading https://files.pythonhosted.org/packages/db/c5/b5e8bc1f40568a354f2a9cc296b8892605a9d2f22e725290fc33836dd2a3/trio_websocket-0.9.2-py3-none-any.whl#sha256=5b558f6e83cc20a37c3b61202476c5295d1addf57bd65543364e0337e37ed2bc
# Best match: trio-websocket 0.9.2
# Processing trio_websocket-0.9.2-py3-none-any.whl
# Installing trio_websocket-0.9.2-py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding trio-websocket 0.9.2 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/trio_websocket-0.9.2-py3.7.egg
# Searching for pyOpenSSL>=0.14
# Reading https://pypi.org/simple/pyOpenSSL/
# Downloading https://files.pythonhosted.org/packages/b2/5e/06351ede29fd4899782ad335c2e02f1f862a887c20a3541f17c3fa1a3525/pyOpenSSL-20.0.1-py2.py3-none-any.whl#sha256=818ae18e06922c066f777a33f1fca45786d85edfe71cd043de6379337a7f274b
# Best match: pyOpenSSL 20.0.1
# Processing pyOpenSSL-20.0.1-py2.py3-none-any.whl
# Installing pyOpenSSL-20.0.1-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding pyOpenSSL 20.0.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/pyOpenSSL-20.0.1-py3.7.egg
# Searching for cryptography>=1.3.4
# Reading https://pypi.org/simple/cryptography/
# Downloading https://files.pythonhosted.org/packages/b2/26/7af637e6a7e87258b963f1731c5982fb31cd507f0d90d91836e446955d02/cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl#sha256=1e056c28420c072c5e3cb36e2b23ee55e260cb04eee08f702e0edfec3fb51959
# Best match: cryptography 3.4.7
# Processing cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl
# Installing cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl to /usr/local/lib/python3.7/dist-packages
# Adding cryptography 3.4.7 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/cryptography-3.4.7-py3.7-linux-x86_64.egg
# Searching for sniffio
# Reading https://pypi.org/simple/sniffio/
# Downloading https://files.pythonhosted.org/packages/52/b0/7b2e028b63d092804b6794595871f936aafa5e9322dcaaad50ebf67445b3/sniffio-1.2.0-py3-none-any.whl#sha256=471b71698eac1c2112a40ce2752bb2f4a4814c22a54a3eed3676bc0f5ca9f663
# Best match: sniffio 1.2.0
# Processing sniffio-1.2.0-py3-none-any.whl
# Installing sniffio-1.2.0-py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding sniffio 1.2.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/sniffio-1.2.0-py3.7.egg
# Searching for outcome
# Reading https://pypi.org/simple/outcome/
# Downloading https://files.pythonhosted.org/packages/0d/bb/f60ce97b304b1979d1fef96b6517af47b9bb026770b1f198b6e921b5edf5/outcome-1.1.0-py2.py3-none-any.whl#sha256=c7dd9375cfd3c12db9801d080a3b63d4b0a261aa996c4c13152380587288d958
# Best match: outcome 1.1.0
# Processing outcome-1.1.0-py2.py3-none-any.whl
# Installing outcome-1.1.0-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding outcome 1.1.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/outcome-1.1.0-py3.7.egg
# Searching for wsproto>=0.14
# Reading https://pypi.org/simple/wsproto/
# Downloading https://files.pythonhosted.org/packages/ea/25/0934b1d00f404d75335b144d4396e01998f25db8953bf54b4d6fe65b80ab/wsproto-1.0.0-py3-none-any.whl#sha256=d8345d1808dd599b5ffb352c25a367adb6157e664e140dbecba3f9bc007edb9f
# Best match: wsproto 1.0.0
# Processing wsproto-1.0.0-py3-none-any.whl
# Installing wsproto-1.0.0-py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding wsproto 1.0.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/wsproto-1.0.0-py3.7.egg
# Searching for h11<1,>=0.9.0
# Reading https://pypi.org/simple/h11/
# Downloading https://files.pythonhosted.org/packages/60/0f/7a0eeea938eaf61074f29fed9717f2010e8d0e0905d36b38d3275a1e4622/h11-0.12.0-py3-none-any.whl#sha256=36a3cb8c0a032f56e2da7084577878a035d3b61d104230d4bd49c0c6b555a9c6
# Best match: h11 0.12.0
# Processing h11-0.12.0-py3-none-any.whl
# Installing h11-0.12.0-py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding h11 0.12.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/h11-0.12.0-py3.7.egg
# Searching for idna==2.10
# Best match: idna 2.10
# Adding idna 2.10 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for certifi==2021.5.30
# Best match: certifi 2021.5.30
# Adding certifi 2021.5.30 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for sortedcontainers==2.4.0
# Best match: sortedcontainers 2.4.0
# Adding sortedcontainers 2.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for attrs==21.2.0
# Best match: attrs 21.2.0
# Adding attrs 21.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for async-generator==1.10
# Best match: async-generator 1.10
# Adding async-generator 1.10 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for six==1.15.0
# Best match: six 1.15.0
# Adding six 1.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for cffi==1.14.6
# Best match: cffi 1.14.6
# Adding cffi 1.14.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pycparser==2.20
# Best match: pycparser 2.20
# Adding pycparser 2.20 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Finished processing dependencies for google-images-download==2.8.0

# %%
from google_images_download import google_images_download
response = google_images_download.googleimagesdownload()
arguments={"keywords":"SK refrigerator","limit":99,"print_url":True}
paths=response.download(arguments)
print(paths)
# Out:
# Item no.: 1 --> Item name = SK refrigerator
# Evaluating...
# Starting Download...
# Completed Image ====> 1.sk%204240.jpg
# Completed Image ====> 2.sk%204260.jpg
# Completed Image ====> 3.sonoko%20refrigerator%20170-500x500.jpg
# Completed Image ====> 4.faerskhet-bottom-freezer-refrigerator-stainless-steel-color__0956332_pe804798_s5.jpg.webp
# Completed Image ====> 5.1588255516151dd2-20-600x600.jpg
# Completed Image ====> 6.santo-85-606-sk.jpg
# Completed Image ====> 7.nasco-refrigerator-bottom-freezer-258-ltr-grossnnasd2-24-sk_1.jpg
# URLError on an image...trying next one... Error: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:
# Completed Image ====> 45.sk%204260.jpg
# Completed Image ====> 46.engel-swing-motor-detail-diagram.jpg
# Completed Image ====> 47.20140418_122024.jpg
# Completed Image ====> 48.s-k-fridge-centre-kolkata-0w2rxghmjo.jpg
# Completed Image ====> 49.sk-skskr24-a.jpg
# Completed Image ====> 50.ref.jpg
# Completed Image ====> 51.pl2639304-ice_lolly_commercial_refrigerator_freezer_sk_series_stainless_steel.jpg
# Completed Image ====> 52.1795772_main.jpg_480wx480h.jpg
# Completed Image ====> 53.png-transparent-aeg-scb61824lf-refrigerator-freezer-white-heureka-sk-freezers-refrigerator-angle-electronics-kitchen-appliance.png
# Completed Image ====> 54.sk-sale-and-purchase-sector-59-phase-4-chandigarh-second-hand-refrigerator-dealers-cf5ruk9dcf.jpg
# Completed Image ====> 55.gagneau-2.jpg
# Completed Image ====> 56.aqua-aqr-i340-sk-1-preview.jpeg
# Completed Image ====> 57.5488_gaggenau_sk_535_262_big.jpg
# Completed Image ====> 58.4017337037049.jpg
# Completed Image ====> 59.579aac34de636b2dc5d5b6212e77fa3f836796bb_000000000001214611_2.jpg
# Completed Image ====> 60.540x360.jpg
# Completed Image ====> 61.51s5sz%2bslrl._ac_sl1000_.jpg
# Completed Image ====> 62.godrej-241l-3starfrost-free-double-door-rte-vibe-256c-35-hci-sk-wn-silky-wine-refrigerator-1-500x500.png
# Completed Image ====> 63.s-k-refrigeration-air-conditioners-hoshiarpur-u1taremcfz.jpg.webp
# Completed Image ====> 64.gagneau-1.jpg
# Completed Image ====> 65.228_326106206785.jpg
# Completed Image ====> 66.3c5f91296abab6ad3e6293fd1cf6fbc2.jpg

# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in /usr/local/lib/python3.7/dist-packages/selenium-4.0.0b4-py3.7.egg (4.0.0b4)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.7/dist-packages/trio_websocket-0.9.2-py3.7.egg (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.7/dist-packages/trio-0.19.0-py3.7.egg (from selenium) (0.19.0)
# Collecting urllib3[secure]~=1.26
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 14.5 MB/s
# Requirement already satisfied: async-generator>=1.9 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: outcome in /usr/local/lib/python3.7/dist-packages/outcome-1.1.0-py3.7.egg (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages/sniffio-1.2.0-py3.7.egg (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.7/dist-packages/wsproto-1.0.0-py3.7.egg (from trio-websocket~=0.9->selenium) (1.0.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in /usr/local/lib/python3.7/dist-packages/pyOpenSSL-20.0.1-py3.7.egg (from urllib3[secure]~=1.26->selenium) (20.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from urllib3[secure]~=1.26->selenium) (2021.5.30)
# Requirement already satisfied: cryptography>=1.3.4 in /usr/local/lib/python3.7/dist-packages/cryptography-3.4.7-py3.7-linux-x86_64.egg (from urllib3[secure]~=1.26->selenium) (3.4.7)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (2.20)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.7/dist-packages/h11-0.12.0-py3.7.egg (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.12.0)
# Installing collected packages: urllib3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.6 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed urllib3-1.26.6
