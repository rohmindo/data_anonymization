# %%
# !ls

# %%
# !git init

# %%
cd drive/MyDrive/mindoRoh_intern/

# %%
# !git add Untitled0.ipynb

# %%
# !git config --global user.email "rohmindo@ajou.ac.kr"
# !git config --global user.name "rohmindo"

# %%
# !git commit -m "test"

# %%
# !git remote add origin "https://github.com/rohmindo/Data_anonymization"

# %%
# !git push --set-upstream origin master

# %%
# !git clone "https://github.com/Saafke/FSRCNN_Tensorflow"

# %%
# !git clone "https://github.com/styler00dollar/Colab-generative-inpainting"

# %%
cd drive/MyDrive/mindoRoh_intern/

# %%
# !git clone "https://github.com/forever208/Transfer_Learning_with_ResNet_on_Colab"

# %%
# !git clone "https://github.com/ayyucekizrak/TransferLearning_FineTuning"

# %%
# !git clone "https://github.com/orenodinner/PConv-Keras-for-google-colab"

# %%
# !git clone "https://github.com/styler00dollar/Colab-mmediting"

# %%
from google.colab import drive
drive.mount('/content/drive')
